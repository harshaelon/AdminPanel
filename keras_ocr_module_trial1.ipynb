# %% [markdown]
# <a href="https://colab.research.google.com/github/harshaelon/AdminPanel/blob/main/keras_ocr_module_trial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q keras-ocr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 56.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 53.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.4 MB/s eta 0:00:00

# %%
# !pip install git+https://github.com/faustomorales/keras-ocr.git#egg=keras-ocr
# Out:
# ...
#   Cloning https://github.com/faustomorales/keras-ocr.git to /tmp/pip-install-um7tq06i/keras-ocr_5c04b58b196c483eac688ab126452565
#   Running command git clone --filter=blob:none --quiet https://github.com/faustomorales/keras-ocr.git /tmp/pip-install-um7tq06i/keras-ocr_5c04b58b196c483eac688ab126452565
#   Resolved https://github.com/faustomorales/keras-ocr.git to commit e8d34a46f07d50158e1d86d6c617e99bfe99e2f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for keras-ocr: filename=keras_ocr-0.0.0-py3-none-any.whl size=42309 sha256=58f8de206f8c98fe2cba2027710331aace2fabad6f592b9373c9a0506a74161e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v7f89mvg/wheels/ee/e8/3a/3915fd372ea68434aa50a06b4b9633c1446cc8b83b5d6975db
# Successfully built keras-ocr
# ...
#   Attempting uninstall: keras-ocr
#     Found existing installation: keras-ocr 0.9.3
#     Uninstalling keras-ocr-0.9.3:
# ...

# %%
import keras_ocr

import matplotlib.pyplot as plt

# %%
from google.colab import drive

drive.mount('\content')
# Out:
# ---------------------------------------------------------------------------
# TIMEOUT                                   Traceback (most recent call last)
# <ipython-input-5-1d35385f5859> in <cell line: 3>()
#       1 from google.colab import drive
#       2
# ----> 3 drive.mount('\content')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     258
#     259   while True:
# --> 260     case = d.expect([
#     261         success,
#     262         prompt,
#
# ...

# %%
pipeline=keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# ...
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...

# %%
images=[
    keras_ocr.tools.read(img) for img in['/content/content/MyDrive/medical_images/checking_pics/Archive-OCR-1.jpg','/content/content/MyDrive/medical_images/checking_pics/eurotext.png','/content/content/MyDrive/medical_images/checking_pics/images.png']
]

# %%
from PIL import Image

fig=plt.figure(figsize=(20,10))

rows=1
columns=3

img1=Image.open('/content/content/MyDrive/medical_images/checking_pics/Archive-OCR-1.jpg')

img2=Image.open('/content/content/MyDrive/medical_images/checking_pics/eurotext.png')

img3=Image.open('/content/content/MyDrive/medical_images/checking_pics/images.png')


fig.add_subplot(rows,columns,1)
plt.imshow(img1)
plt.title('Image-1')
plt.axis('off')


#second_image


fig.add_subplot(rows,columns,2)
plt.imshow(img2)
plt.axis('off')
plt.title('image_2')


#third_image

fig.add_subplot(rows,columns,3)
plt.imshow(img3)
plt.axis('off')
plt.title('image_3')
# Out:
# Text(0.5, 1.0, 'image_3')

# %%
#now to get predictions from the images

prediction_groups=pipeline.recognize(images)
# Out:
# ...
# 6/6 [==============================] - 44s 7s/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image,
                                    predictions=predictions,
                                    ax=ax)

# %%
# !pip install opncv

import cv2 as cv2

extracted_texts = []

# Loop through each image

    # Use the keras_ocr pipeline to recognize text in the image
predictions = pipeline.recognize([image])

    # Extract text from the predictions
text = ' '.join([text for _, text in predictions[0]])

    # Append the extracted text to the list
extracted_texts.append(text)

# Print the extracted texts
for i, text in enumerate(extracted_texts, 1):
    print(f"Text from image {i}:")
    print(text)
    print()
# Out:
# ERROR: Could not find a version that satisfies the requirement opncv (from versions: none)
# ERROR: No matching distribution found for opncv
# ...
# 3/3 [==============================] - 16s 5s/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0169a588e3fc> in <cell line: 13>()
#      11
#      12     # Extract text from the predictions
# ---> 13 text = ' '.join([text for _, text in predictions[0]])
#      14
#      15     # Append the extracted text to the list
#
# TypeError: sequence item 0: expected str instance, numpy.ndarray found

# %%
predicted_image_1=prediction_groups[0]
l1=[]
s=''
for text,box in predicted_image_1:
  print(text)
  l1.append(text)

x1=s.join(l1)
# Out:
# obtained
# informat
# fur
# ther
# ion
# be
# may
# and
# chemistrys
# fellow
# lecturer
# moaes
# in
# s
# crofs
# gilligan
# as
# desces
# dep
# from
# tment
# ar
# leedsy
# and
# ho
# worrally
# from
# mre
# ac
# meass
# colleges
# jerseys

# %%
l1
# Out:
# ['obtained',
#  'informat',
#  'fur',
#  'ther',
#  'ion',
#  'be',
#  'may',
#  'and',
#  'chemistrys',
#  'fellow',
#  'lecturer',
#  'moaes',
#  'in',
#  's',
#  'crofs',
#  'gilligan',
#  'as',
#  'desces',
#  'dep',
#  'from',
#  'tment',
#  'ar',
#  'leedsy',
#  'and',
#  'ho',
#  'worrally',
#  'from',
#  'mre',
#  'ac',
#  'meass',
#  'colleges',
#  'jerseys']

# %%
x1=''

# %%
for i in l1:
  x2=i
  x1+=x2+' '


print(x1)
# Out:
#                                                                 obtained informat fur ther ion be may and chemistrys fellow lecturer moaes in s crofs gilligan as desces dep from tment ar leedsy and ho worrally from mre ac meass colleges jerseys

# %%
import re

# Given string
text = "obtainedinformatfurtherionbemayandchemistrysfellowlecturermoaesinscrofsgilliganasdescesdepfromtmentarleedsyandhoworrallyfrommreacmeasscollegesjerseys"

# Define a regular expression pattern to match word boundaries
pattern = r'[A-Z][a-z]*'

# Use the findall method to extract words from the text using the regular expression pattern
words = re.findall(pattern, text)

# Print the extracted words
print("Extracted words:")
for word in words:
    print(word)
# Out:
# Extracted words:
